# %%
import yfinance as yf
import pandas as pd

# %%
data = yf.download(  # or pdr.get_data_yahoo(...
        # tickers list or string as well
        tickers = "SPY AAPL MSFT",
        
        start='2019-01-01',
        end = '2022-12-31',

        # use "period" instead of start/end
        # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
        # (optional, default is '1mo')
        # period = "5d",

        # fetch data by interval (including intraday if period < 60 days)
        # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
        # (optional, default is '1d')
        interval = "1d",

        # Whether to ignore timezone when aligning ticker data from 
        # different timezones. Default is True. False may be useful for 
        # minute/hourly data.
        ignore_tz = False,

        # group by ticker (to access via data['SPY'])
        # (optional, default is 'column')
        group_by = 'column',

        # adjust all OHLC automatically
        # (optional, default is False)
        auto_adjust = True,

        # attempt repair of missing data or currency mixups e.g. $/cents
        repair = False,

        # download pre/post regular market hours data
        # (optional, default is False)
        prepost = True,

        # use threads for mass downloading? (True/False/Integer)
        # (optional, default is True)
        threads = True,

        # proxy URL scheme use use when downloading?
        # (optional, default is None)
        proxy = None
    )
data
# Out:
# [*********************100%***********************]  3 of 3 completed
#                                 Close                                High  \
#                                  AAPL        MSFT         SPY        AAPL
# Date
# 2019-01-02 00:00:00-05:00   38.105133   96.874702  234.061615   38.329538
# 2019-01-03 00:00:00-05:00   34.309574   93.310867  228.476257   35.161341
# 2019-01-04 00:00:00-05:00   35.774239   97.650681  236.129272   35.844216
# 2019-01-07 00:00:00-05:00   35.694611   97.775246  237.991043   35.911777
# 2019-01-08 00:00:00-05:00   36.375053   98.484169  240.227020   36.633240
# ...                               ...         ...         ...         ...
# 2022-12-23 00:00:00-05:00  131.860001  238.729996  382.910004  132.419998
# 2022-12-27 00:00:00-05:00  130.029999  236.960007  381.399994  131.410004
# 2022-12-28 00:00:00-05:00  126.040001  234.529999  376.660004  131.029999
# 2022-12-29 00:00:00-05:00  129.610001  241.009995  383.440002  130.479996
# ...

# %%
data.index
# Out:
# DatetimeIndex(['2019-01-02 00:00:00-05:00', '2019-01-03 00:00:00-05:00',
#                '2019-01-04 00:00:00-05:00', '2019-01-07 00:00:00-05:00',
#                '2019-01-08 00:00:00-05:00', '2019-01-09 00:00:00-05:00',
#                '2019-01-10 00:00:00-05:00', '2019-01-11 00:00:00-05:00',
#                '2019-01-14 00:00:00-05:00', '2019-01-15 00:00:00-05:00',
#                ...
#                '2022-12-16 00:00:00-05:00', '2022-12-19 00:00:00-05:00',
#                '2022-12-20 00:00:00-05:00', '2022-12-21 00:00:00-05:00',
#                '2022-12-22 00:00:00-05:00', '2022-12-23 00:00:00-05:00',
#                '2022-12-27 00:00:00-05:00', '2022-12-28 00:00:00-05:00',
#                '2022-12-29 00:00:00-05:00', '2022-12-30 00:00:00-05:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=1008, freq=None)

# %%
#For complete month of Jan 2019
data.loc['2019-01']
# Out:
#                                Close                               High  \
#                                 AAPL        MSFT         SPY       AAPL
# Date
# 2019-01-02 00:00:00-05:00  38.105133   96.874702  234.061615  38.329538
# 2019-01-03 00:00:00-05:00  34.309574   93.310867  228.476257  35.161341
# 2019-01-04 00:00:00-05:00  35.774239   97.650681  236.129272  35.844216
# 2019-01-07 00:00:00-05:00  35.694611   97.775246  237.991043  35.911777
# 2019-01-08 00:00:00-05:00  36.375053   98.484169  240.227020  36.633240
# 2019-01-09 00:00:00-05:00  36.992771   99.892448  241.349747  37.287150
# 2019-01-10 00:00:00-05:00  37.111000   99.250587  242.201141  37.152020
# 2019-01-11 00:00:00-05:00  36.746647   98.484169  242.294693  37.086872
# 2019-01-14 00:00:00-05:00  36.194092   97.765656  240.816452  36.500536
# 2019-01-15 00:00:00-05:00  36.934868  100.601387  243.576416  37.012080
# 2019-01-16 00:00:00-05:00  37.386089  100.955841  244.165802  37.612906
# ...

# %%
#Date range for filtering
data.loc['2019-01-01':'2019-01-10']
# Out:
#                                Close                              High  \
#                                 AAPL       MSFT         SPY       AAPL
# Date
# 2019-01-02 00:00:00-05:00  38.105133  96.874702  234.061615  38.329538
# 2019-01-03 00:00:00-05:00  34.309574  93.310867  228.476257  35.161341
# 2019-01-04 00:00:00-05:00  35.774239  97.650681  236.129272  35.844216
# 2019-01-07 00:00:00-05:00  35.694611  97.775246  237.991043  35.911777
# 2019-01-08 00:00:00-05:00  36.375053  98.484169  240.227020  36.633240
# 2019-01-09 00:00:00-05:00  36.992771  99.892448  241.349747  37.287150
# 2019-01-10 00:00:00-05:00  37.111000  99.250587  242.201141  37.152020
#
#                                                          Low             \
#                                  MSFT         SPY       AAPL       MSFT
# Date
# 2019-01-02 00:00:00-05:00   97.478251  235.025268  37.214758  94.786225
# 2019-01-03 00:00:00-05:00   95.983736  232.555356  34.263728  93.119260
# ...

# %%
#Closing prices of AAPL stock for Jan-2019

data.loc['2019-01']['Close']['AAPL']
# Out:
# Date
# 2019-01-02 00:00:00-05:00    38.105133
# 2019-01-03 00:00:00-05:00    34.309574
# 2019-01-04 00:00:00-05:00    35.774239
# 2019-01-07 00:00:00-05:00    35.694611
# 2019-01-08 00:00:00-05:00    36.375053
# 2019-01-09 00:00:00-05:00    36.992771
# 2019-01-10 00:00:00-05:00    37.111000
# 2019-01-11 00:00:00-05:00    36.746647
# 2019-01-14 00:00:00-05:00    36.194092
# 2019-01-15 00:00:00-05:00    36.934868
# 2019-01-16 00:00:00-05:00    37.386089
# 2019-01-17 00:00:00-05:00    37.608074
# 2019-01-18 00:00:00-05:00    37.839714
# 2019-01-22 00:00:00-05:00    36.990364
# 2019-01-23 00:00:00-05:00    37.139957
# 2019-01-24 00:00:00-05:00    36.845581
# 2019-01-25 00:00:00-05:00    38.066532
# 2019-01-28 00:00:00-05:00    37.714241
# 2019-01-29 00:00:00-05:00    37.323353
# 2019-01-30 00:00:00-05:00    39.873825
# 2019-01-31 00:00:00-05:00    40.160969
# Name: AAPL, dtype: float64

# %%
# Mean stock price for AAPL stock for Jan 2019
data.loc['2019-01']['Close']['AAPL'].mean()
# Out:
# 37.199366069975355

# %%
# Resampling Stock closing values based on monthly mean

## Sample for period https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#offset-aliases
# (M, D, SM, B, SMS, BMS etc.)

data['Close'].resample('M').mean()
# Out:
#                                  AAPL        MSFT         SPY
# Date
# 2019-01-31 00:00:00-05:00   37.199366   99.763350  243.346523
# 2019-02-28 00:00:00-05:00   41.567929  103.563802  257.502653
# 2019-03-31 00:00:00-04:00   44.417369  110.771227  262.596180
# 2019-04-30 00:00:00-04:00   48.590848  118.141895  272.290157
# 2019-05-31 00:00:00-04:00   46.468255  121.804449  268.096785
# 2019-06-30 00:00:00-04:00   46.942026  127.462640  271.956677
# 2019-07-31 00:00:00-04:00   49.921343  133.361652  282.300217
# 2019-08-31 00:00:00-04:00   49.997227  131.953580  273.458037
# 2019-09-30 00:00:00-04:00   53.231384  133.818108  281.939415
# 2019-10-31 00:00:00-04:00   57.453737  134.897103  281.856233
# 2019-11-30 00:00:00-05:00   64.258690  143.661611  294.345929
# 2019-12-31 00:00:00-05:00   67.726506  149.890625  301.679470
# 2020-01-31 00:00:00-05:00   76.394322  159.436994  311.701352
# 2020-02-29 00:00:00-05:00   76.378134  173.940747  312.080642
# ...

# %%
# %matplotlib inline
data['Close'].resample('M').mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
rng = pd.date_range(start= '2020-01-01',
                   end = '2020-01-31')
rng
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10', '2020-01-11', '2020-01-12',
#                '2020-01-13', '2020-01-14', '2020-01-15', '2020-01-16',
#                '2020-01-17', '2020-01-18', '2020-01-19', '2020-01-20',
#                '2020-01-21', '2020-01-22', '2020-01-23', '2020-01-24',
#                '2020-01-25', '2020-01-26', '2020-01-27', '2020-01-28',
#                '2020-01-29', '2020-01-30', '2020-01-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
rng = pd.date_range(start= '2020-01-01',
                   end = '2020-01-31', freq = 'B')
rng
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-06',
#                '2020-01-07', '2020-01-08', '2020-01-09', '2020-01-10',
#                '2020-01-13', '2020-01-14', '2020-01-15', '2020-01-16',
#                '2020-01-17', '2020-01-20', '2020-01-21', '2020-01-22',
#                '2020-01-23', '2020-01-24', '2020-01-27', '2020-01-28',
#                '2020-01-29', '2020-01-30', '2020-01-31'],
#               dtype='datetime64[ns]', freq='B')

# %%
data.asfreq('D',method='pad')
# Out:
#                                 Close                                High  \
#                                  AAPL        MSFT         SPY        AAPL
# Date
# 2019-01-02 00:00:00-05:00   38.105133   96.874702  234.061615   38.329538
# 2019-01-03 00:00:00-05:00   34.309574   93.310867  228.476257   35.161341
# 2019-01-04 00:00:00-05:00   35.774239   97.650681  236.129272   35.844216
# 2019-01-05 00:00:00-05:00   35.774239   97.650681  236.129272   35.844216
# 2019-01-06 00:00:00-05:00   35.774239   97.650681  236.129272   35.844216
# ...                               ...         ...         ...         ...
# 2022-12-26 00:00:00-05:00  131.860001  238.729996  382.910004  132.419998
# 2022-12-27 00:00:00-05:00  130.029999  236.960007  381.399994  131.410004
# 2022-12-28 00:00:00-05:00  126.040001  234.529999  376.660004  131.029999
# 2022-12-29 00:00:00-05:00  129.610001  241.009995  383.440002  130.479996
# 2022-12-30 00:00:00-05:00  129.929993  239.820007  382.429993  129.949997
#
# ...

# %%
pd.date_range(start= '2022-07-01', end = '2022-07-15', freq = 'D')
# Out:
# DatetimeIndex(['2022-07-01', '2022-07-02', '2022-07-03', '2022-07-04',
#                '2022-07-05', '2022-07-06', '2022-07-07', '2022-07-08',
#                '2022-07-09', '2022-07-10', '2022-07-11', '2022-07-12',
#                '2022-07-13', '2022-07-14', '2022-07-15'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start= '2022-07-01', end = '2022-07-15', freq = 'B')
# Out:
# DatetimeIndex(['2022-07-01', '2022-07-04', '2022-07-05', '2022-07-06',
#                '2022-07-07', '2022-07-08', '2022-07-11', '2022-07-12',
#                '2022-07-13', '2022-07-14', '2022-07-15'],
#               dtype='datetime64[ns]', freq='B')

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay

usbd = CustomBusinessDay(calendar=USFederalHolidayCalendar())
print(type(usbd))
pd.date_range(start= '2022-07-01', end = '2022-07-15', freq = usbd)
# Out:
# <class 'pandas._libs.tslibs.offsets.CustomBusinessDay'>
# DatetimeIndex(['2022-07-01', '2022-07-05', '2022-07-06', '2022-07-07',
#                '2022-07-08', '2022-07-11', '2022-07-12', '2022-07-13',
#                '2022-07-14', '2022-07-15'],
#               dtype='datetime64[ns]', freq='C')

# %%
# Custom Business holiday

# Observance Freq more details - https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html?highlight=observance%20calendar#holidays-holiday-calendars


from pandas.tseries.holiday import AbstractHolidayCalendar, nearest_workday, Holiday

class AnyDay(AbstractHolidayCalendar):
    '''US Federal Government Holiday Calendar based on rules specified by:
    https://waw.opm.gov/policy-data -oversight/
    snow-dismissal-procedures/federal - holidays/
    '''
    rules = [
        Holiday('Special Holiday I added', month=7, day=10, observance=nearest_workday),
        ]
    
custom_bd = CustomBusinessDay(calendar = AnyDay())
pd.date_range(start= '2022-07-01', end = '2022-07-15', freq = custom_bd)
# Out:
# DatetimeIndex(['2022-07-01', '2022-07-04', '2022-07-05', '2022-07-06',
#                '2022-07-07', '2022-07-08', '2022-07-12', '2022-07-13',
#                '2022-07-14', '2022-07-15'],
#               dtype='datetime64[ns]', freq='C')

# %%
## Change work week from Sun to Thu instead of Default Mon to Fri and a custom Holiday

new_week = CustomBusinessDay(weekmask= 'Sun Mon Tue Wed Thu', holidays=['2022-07-05'])
pd.date_range(start= '2022-07-01', end = '2022-07-15', freq = new_week)
# Out:
# DatetimeIndex(['2022-07-03', '2022-07-04', '2022-07-06', '2022-07-07',
#                '2022-07-10', '2022-07-11', '2022-07-12', '2022-07-13',
#                '2022-07-14'],
#               dtype='datetime64[ns]', freq='C')

# %% [markdown]
# ## Changing Different format dates to DateTime

# %%
dates = ['4th Jan 2022', '2022/01/04 14:30:00', 'Jan 4, 2022 4:30pm', '2022.01.04', '20220104']
pd.to_datetime(dates)
# Out:
# DatetimeIndex(['2022-01-04 00:00:00', '2022-01-04 14:30:00',
#                '2022-01-04 16:30:00', '2022-01-04 00:00:00',
#                '2022-01-04 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
#Custom Format dates

pd.to_datetime('2022$04##01', format='%Y$%d##%m')
# Out:
# Timestamp('2022-01-04 00:00:00')

# %%
t = 1654224453
dt = pd.to_datetime([t], unit = 's') #default value of unit is ns
dt
# Out:
# DatetimeIndex(['2022-06-03 02:47:33'], dtype='datetime64[ns]', freq=None)

# %%
dt.view('int64')
# Out:
# array([1654224453000000000])

# %%
## Time Stamp and Time Period

y = pd.Period(2022)
y
# Out:
# Period('2022', 'A-DEC')

# %%
print(y.start_time)
print(y.end_time)
# Out:
# 2022-01-01 00:00:00
# 2022-12-31 23:59:59.999999999

# %%
m = pd.Period(2022, freq='M')
m
# Out:
# Period('2022-01', 'M')

# %%
print(m.start_time)
print(m.end_time)
# Out:
# 2022-01-01 00:00:00
# 2022-01-31 23:59:59.999999999

# %%
m2 = m + 1
m2
# Out:
# Period('2022-02', 'M')

# %%
print(m2.start_time)
print(m2.end_time)
# Out:
# 2022-02-01 00:00:00
# 2022-02-28 23:59:59.999999999

# %%
d = pd.Period('2022-01-04')
d
# Out:
# Period('2022-01-04', 'D')

# %%
H = pd.Period('2022-01-04 23')
H
# Out:
# Period('2022-01-04 23:00', 'H')

# %%
S = pd.Period('2022-01-04 23:00:00')
S
# Out:
# Period('2022-01-04 23:00:00', 'S')

# %%
H = pd.Period('2022-01-04 23:00:00', freq='H')
H
# Out:
# Period('2022-01-04 23:00', 'H')
